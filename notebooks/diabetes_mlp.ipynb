# %% [markdown]
# # 🍬 Prediksi Diabetes Pasien
# ## Project Machine Learning - CS2025
# **Nama:**
# **NIM:**
#
# ### Dataset: Diabetes Dataset (UCI)

# %%
# --- IMPORT LIBRARIES ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import os
import time

print("✅ Libraries imported")

# %%
# --- LOAD DATASET ---
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/diabetes/diabetes.data"
df = pd.read_csv(url, header=None, delim_whitespace=True)
df.columns = ['Num_Pregnancies','Glucose','Blood_Pressure','Skin_Thickness','Insulin','BMI','Diabetes_Pedigree','Age','Class']

# Preprocessing target
df['Class'] = df['Class'].apply(lambda x: 0 if x == 0 else 1)

print(f"Dataset shape: {df.shape}")
print(df.head())

# %% [markdown]
# ### 🧠 Model Architecture: MLP Neural Network

# %%
# --- BUILD AND TRAIN MODEL ---
# KODE MODEL ANDA DI SINI
# Copy-paste kode training model Anda di cell ini

print("📝 Copy kode training Anda di sini")
